# %% [markdown]
# <a href="https://colab.research.google.com/github/YongjaeKwon0629/07_03_Numpy/blob/main/07_03_w3school_matpolib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Matplotlib이란 무엇인가요?**
# Matplotlib은 시각화 유틸리티 역할을 하는 파이썬의 저수준 그래프 플로팅 라이브러리입니다.
#
# Matplotlib은 John D. Hunter가 만들었습니다.
#
# Matplotlib은 오픈 소스이므로 자유롭게 사용할 수 있습니다.
#
# Matplotlib은 대부분 Python으로 작성되었으며, 일부 부분은 플랫폼 호환성을 위해 C, Objective-C 및 Javascript로 작성되었습니다.

# %% [markdown]
# # **Matplotlib 시작하기**
#
#   **Matplotlib 설치**
#
#   시스템에 이미 Python 과 PIP가 설치되어 있다면 Matplotlib을 설치하는 것은 매우 쉽습니다.
#
# 다음 명령어를 사용하여 설치하세요:
# **"C:\Users\Your Name>pip install matplotlib"**
# 이 명령이 실패하면 Anaconda, Spyder 등과 같이 Matplotlib이 이미 설치된 Python 배포판을 사용하세요.

# %% [markdown]
# **Matplotlib 가져오기**
# Matplotlib이 설치되면 다음 명령문을 추가하여 애플리케이션에 가져옵니다 **.import module**

# %%
import matplotlib

# %% [markdown]
# 이제 Matplotlib을 가져와서 사용할 준비가 되었습니다.

# %% [markdown]
# **Matplotlib 버전 확인**
#
# 버전 문자열은 __version__ 속성에 저장됩니다.
#
# **예**

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# **참고:** 밑줄 문자 두 개가 사용됩니다 __version__.

# %% [markdown]
# # **Matplotlib Pyplot**

# %% [markdown]
# **파이플롯**
# 대부분의 Matplotlib 유틸리티는 **pyplot**하위 모듈에 속하며 일반적으로 다음 별칭으로 가져옵니다 **plt**.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 이제 **Pyplot** 패키지를 .이라고도 합니다 **plt**.
#
# **예**
#
#
# 다이어그램에서 위치 (0,0)에서 위치 (6,250)까지 선을 그립니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # **Matplotlib 플로팅**

# %% [markdown]
# **x 및 y 점 표시**
# 이 **plot()**함수는 다이어그램에 점(마커)을 그리는 데 사용됩니다.
#
# 기본적으로 이 plot()함수는 지점 간에 선을 그립니다.
#
# 이 함수는 다이어그램의 지점을 지정하기 위한 매개변수를 사용합니다.
#
# **매개변수 1은 x축의** 점을 포함하는 배열입니다 .
#
# **매개변수 2는 y축의** 점을 포함하는 배열입니다 .
#
# (1, 3)에서 (8, 10)까지 선을 그려야 하는 경우 plot 함수에 두 개의 배열 [1, 8]과 [3, 10]을 전달해야 합니다.
#
# **예**
# 다이어그램에서 위치 (1, 3)에서 위치 (8, 10)까지 선을 그립니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **선 없이 플로팅**
#
# 마커만 표시하려면 단축 문자열 표기 매개변수 'o'를 사용하면 되는데, 이는 '고리'를 의미합니다.
#
# **예**
#
# 다이어그램에 두 점을 그립니다. 하나는 위치 (1, 3)에, 다른 하나는 위치 (8, 10)에 있습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# **여러 점**
#
# 원하는 만큼 많은 점을 표시할 수 있지만, 두 축에 같은 수의 점이 있는지 확인하세요.
#
# **예**
#
# 다이어그램에서 위치 (1, 3)에서 (2, 8)까지, 그 다음 (6, 1)까지, 마지막으로 위치 (8, 10)까지 선을 그립니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **기본 X-포인트**
#
#
# x축의 점을 지정하지 않으면 y점의 길이에 따라 0, 1, 2, 3 등의 기본값이 지정됩니다.
#
# 따라서 위와 같은 예를 취하고 x점을 제외하면 다이어그램은 다음과 같습니다.
#
# **예**
#
# X점 없이 플로팅:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # **Matplotlib 마커**

# %% [markdown]
# **마커**
#
#   키워드 인수를 사용하면 **marker**지정된 마커로 각 지점을 강조할 수 있습니다.
#
# **예**
#
# 각 지점을 원으로 표시하세요.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# **예**
#
#
# 각 지점을 별표로 표시하세요.

# %%
plt.plot(ypoints, marker = '*')

# %% [markdown]
# **형식 문자열fmt**
# 또한, 단축키 문자열 표기법 매개변수를 사용하여 마커를 지정할 수도 있습니다.
#
# 이 매개변수는 라고도 불리며 다음 구문으로 작성됩니다.
#
# marker|line|color
#
# **예**
# 각 지점을 원으로 표시하세요.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# 마커 값은 위의 마커 참조에서 가져온 어떤 것이든 될 수 있습니다.
# **참고: fmt 매개변수에서** 줄 값을 생략하면 줄이 그려지지 않습니다.

# %% [markdown]
# **마커 크기**
# 키워드 인수 **markersize**나 더 짧은 버전을 사용하여 **ms**마커의 크기를 설정할 수 있습니다.
#
# **예**
#
# 마커 크기를 20으로 설정합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# **마커 색상**
# 키워드 인수 **markeredgecolor**나 더 짧은 인수를 사용하여 마커 가장자리**mec** 의 색상을 설정할 수 있습니다.
#
# **예**
#
# EDGE 색상을 빨간색으로 설정합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# 키워드 인수 **markerfacecolor**나 더 짧은 인수를 사용하여 **mfc**마커 가장자리 내부의 색상을 설정할 수 있습니다.
# **예**
#
# FACE 색상을 빨간색으로 설정합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# **mec** 및 **mfc** 모두 사용하여 마커 전체를 색칠합니다.
#
# **예**
#
# 모서리 와 면 의 색상을 모두 빨간색으로 설정합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r', mec = 'r')

# %% [markdown]
# 16진수 색상 값을 사용할 수도 있습니다 .
#
# **예**
#
# 각 지점을 아름다운 녹색으로 표시하세요

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mfc = '#4CAF50', mec = '#4CAF50')

# %% [markdown]
# 또는 **지원되는 140개 색상 이름** 중 하나를 선택하세요.
#
# **예**
#
# 각 지점을 "핫핑크"라는 색상으로 표시하세요.

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
...
# Out:
# Ellipsis

# %% [markdown]
# # **Matplotlib 라인**

# %% [markdown]
# **선 스타일**
#
# 키워드 인수 **linestyle** 또는 더 짧은 **ls**를 사용하여 그려진 선의 스타일을 변경할 수 있습니다.
#
# **예**
# 점선을 사용하세요:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %% [markdown]
# **예**
#
# 점선을 사용하세요:

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# **더 짧은 구문**
#
# 선 스타일은 더 짧은 구문으로 작성할 수 있습니다.
#
# linestyle은 ls로 쓸 수 있습니다.
#
# dotted는 :로 쓸 수 있습니다 :.
#
# dashed는 -로 쓸 수 있습니다 --.
#
#
# **예**
#
# 더 짧은 구문:

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# **선 스타일**
#
# 다음 스타일 중에서 선택할 수 있습니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **선 색상**
#
# 키워드 인수 **color**나 더 짧은 인수 **c**를 사용하여 선의 색상을 설정할 수 있습니다.
#
# **예**
#
#
# 선 색상을 빨간색으로 설정합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# **16진수 색상 값**을 사용할 수도 있습니다.
#
# **예**
#
#
# 아름다운 녹색 선이 있는 플롯:

# %%
plt.plot(ypoints, c = '#4CAF50')

# %% [markdown]
# 또는 **지원되는 140개 색상 이름** 중 하나를 선택하세요.
#
# **예**
# "hotpink"라는 이름의 색상이 있는 플롯:

# %%
plt.plot(ypoints, c = 'hotpink')

# %% [markdown]
# **선 너비**
#
# **linewidth** 키워드 인수나 더 짧은 **lw**를 사용해 줄의 너비를 변경할 수 있습니다.
#
# 값은 포인트 단위의 부동 소수점 숫자입니다.
#
# **예**
#
# 20.5pt 폭의 선이 있는 플롯:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# **여러 줄**
#
#
# 더 많은 함수를 추가하면 원하는 만큼 많은 선을 그릴 수 있습니다.
#
#
# **plt.plot**()
#
# **예**
#
#
# **plt.plot():** 각 선에 함수를 지정하여 두 개의 선을 그립니다 .

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# 동일한 함수에서 각 선에 대한 x축과 y축에 대한 점을 추가하여 많은 선을 그릴 수도 있습니다 **plt.plot().**
#
# (위의 예에서는 y축의 점만 지정했기 때문에 x축의 점에는 기본값(0, 1, 2, 3)이 적용되었습니다.)
#
# x 및 y 값은 쌍으로 제공됩니다.
#
#
#
# **예**
#
#
# 두 선의 x 및 y 점 값을 지정하여 두 선을 그립니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array([0,1,2,3])
y1=np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # **Matplotlib 레이블 및 제목**

# %% [markdown]
# **플롯에 대한 레이블 만들기**
# Pyplot을 사용하면**xlabel()** 및 **ylabel()**함수를 사용하여 x축과 y축에 대한 레이블을 설정할 수 있습니다.
#
# **예**
#
# x축과 y축에 레이블을 추가합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y=np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# **플롯의 제목 만들기**
# **title()** Pyplot을 사용하면 플롯의 제목을 설정하는 함수를 사용할 수 있습니다.
#
# **예**
#
#
# x축과 y축에 대한 플롯 제목과 레이블을 추가합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y=np.array([240, 250,260,270,280,290,300,310,320,330])

plt.plot(x,y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# **제목 및 레이블에 대한 글꼴 속성 설정**
#
#
# 제목과 레이블의 글꼴 속성을 설정하려면 **xlabel(), ylabel(), title(),fontdict**의 매개변수 를 사용할 수 있습니다.
#
# **예**
#
# 제목과 레이블에 대한 글꼴 속성을 설정합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# **제목 위치 지정**
#
#
# **loc** 매개변수를 사용하여 **title()** 제목의 위치를 ​​지정할 수 있습니다.
#
# 유효한 값은 'left', 'right', 'center'입니다. 기본값은 'center'입니다.
#
# **예**
#
# 제목을 왼쪽에 배치하세요:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # **Matplotlib 그리드 선 추가**

# %% [markdown]
# **플롯에 격자선 추가**
# **grid()** Pyplot을 사용하면 플롯에 격자선을 추가하는 함수를 사용할 수 있습니다 .

# %% [markdown]
# **예**
#
# 플롯에 격자선 추가:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# **표시할 격자선 지정**
#
# **grid()** 함수의 매개변수 **axis** 를 사용하여 표시할 격자선을 지정할 수 있습니다.
#
# 유효한 값은 'x', 'y', 'both'입니다. 기본값은 'both'입니다.

# %% [markdown]
# **예**
#
#
# x축에 대한 격자선만 표시합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# **예**
#
#
# y축에 대한 격자선만 표시합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# **그리드의 선 속성 설정**
# 다음과 같이 그리드의 선 속성을 설정할 수도 있습니다:
#  grid(color = ' color ', linestyle = ' linestyle ', linewidth = number ).

# %% [markdown]
# **예**
# 그리드의 선 속성을 설정합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

# 1번: 센서 초기화
def init_sensors():
    sensors = {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
    print("[1] 센서 초기화:", sensors)
    return sensors

# 2~4번: 센서 스캔
def scan_front(x, y, obstacles, sensors):
    front_distance = 15.0
    for ox, oy in obstacles:
        if ox == x and oy > y:
            distance = oy - y
            if distance < front_distance:
                front_distance = distance
    sensors['앞'] = front_distance
    print(f"[Front Scan] 현재 앞 센서 거리: {sensors['앞']}cm")
    if front_distance <= 5.0:
        print("[Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)")
    elif front_distance <= 10.0:
        print("[Front Scan] 앞에 장애물이 가까움 (10cm 이하)")
    elif front_distance <= 15.0:
        print("[Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Front Scan] 앞에 장애물 없음, 직진 가능")
    print("[Front Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

def scan_left(x, y, obstacles, sensors):
    left_distance = 15.0
    for ox, oy in obstacles:
        if oy == y and ox < x:
            distance = x - ox
            if distance < left_distance:
                left_distance = distance
    sensors['왼쪽'] = left_distance
    print(f"[Left Scan] 현재 왼쪽 센서 거리: {sensors['왼쪽']}cm")
    if left_distance <= 5.0:
        print("[Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)")
    elif left_distance <= 10.0:
        print("[Left Scan] 왼쪽에 장애물이 가까움 (10cm 이하)")
    elif left_distance <= 15.0:
        print("[Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Left Scan] 왼쪽에 장애물 없음, 좌회전 가능")
    print("[Left Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

def scan_right(x, y, obstacles, sensors):
    right_distance = 15.0
    for ox, oy in obstacles:
        if oy == y and ox > x:
            distance = ox - x
            if distance < right_distance:
                right_distance = distance
    sensors['오른쪽'] = right_distance
    print(f"[Right Scan] 현재 오른쪽 센서 거리: {sensors['오른쪽']}cm")
    if right_distance <= 5.0:
        print("[Right Scan] 오른쪽에 장애물이 매우 가까움! (5cm 이하)")
    elif right_distance <= 10.0:
        print("[Right Scan] 오른쪽에 장애물이 가까움 (10cm 이하)")
    elif right_distance <= 15.0:
        print("[Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Right Scan] 오른쪽에 장애물 없음, 우회전 가능")
    print("[Right Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

# 5번: 센서 데이터 업데이트
def update_sensor_data(position, obstacles):
    print("[5-4] 센서 데이터 업데이트 시작")
    x, y = position
    print(f"[5-6] 현재 위치: x={x}, y={y}")
    sensors = init_sensors()
    sensors = scan_front(x, y, obstacles, sensors)
    sensors = scan_left(x, y, obstacles, sensors)
    sensors = scan_right(x, y, obstacles, sensors)
    print("[5-17] 센서 데이터 업데이트 완료:", sensors)
    return sensors

# 6번: 장애물 감지
def detect_obstacles(sensors):
    print("[6-4] 함수 시작")
    obstacles = []
    for direction, distance in sensors.items():
        print(f"[6-9] 현재 방향: {direction}, 거리: {distance}")
        if distance < 10.0:
            obstacles.append(direction)
            print(f"[6-12]⚠️ 위험! {direction} 방향 → 목록에 추가됨 (거리 {distance} < 10.0)")
        else:
            print(f"[6-14] ✅ 안전 {direction} 방향 (거리 {distance} ≥ 10.0)")
    print("[6-16] 장애물 감지 완료 → 최종 obstacles 리스트:", obstacles)
    return obstacles

# 7번: 행동 결정
def decide_action(obstacles):
    print("[7] 행동 결정 시작")
    if '앞' not in obstacles and '왼쪽' not in obstacles and '오른쪽' not in obstacles:
        action = "전진"
    elif '앞' in obstacles and '왼쪽' not in obstacles:
        action = "왼쪽 회전"
    elif '앞' in obstacles and '오른쪽' not in obstacles:
        action = "오른쪽 회전"
    elif '앞' in obstacles and '왼쪽' in obstacles and '오른쪽' in obstacles:
        action = "정지"
    else:
        action = "전진"
    print("[7] 행동 결정 완료 →", action)
    return action

# 시각화 함수
def visualize_map(car_position, path_history, obstacles, step):
    grid_size = 7
    plt.clf()
    plt.title(f"[시각화] Step {step} 자동차 위치")
    plt.xlim(-1, grid_size)
    plt.ylim(-1, grid_size)
    plt.xticks(range(grid_size))
    plt.yticks(range(grid_size))
    plt.grid(True)

    # 장애물
    for ox, oy in obstacles:
        plt.plot(ox, oy, 'ks', markersize=20)

    # 경로 (선으로 연결)
    if len(path_history) > 1:
        xs, ys = zip(*path_history)
        plt.plot(xs, ys, 'b--', linewidth=2, label='이동 경로')

    # 현재 위치 + 라벨
    x, y = car_position
    plt.plot(x, y, 'ro', markersize=20, label='자동차')
    plt.text(x + 0.1, y + 0.1, f"Step {step}", fontsize=9)

    plt.gca().set_aspect('equal', adjustable='box')
    plt.legend(loc='upper right')
    plt.pause(0.7)

# 8번: 자동차 클래스
class SimpleCar:
    def __init__(self, name, x, y):
        self.name = name
        self.position = (x, y)
        self.path = [self.position]
        print(f"[Car Init] 자동차 {self.name} 생성, 초기 위치: {self.position}")

    def move_forward(self):
        x, y = self.position
        self.position = (x, y + 1)
        print(f"[Move] 전진 → 새로운 위치: {self.position}")

    def turn_left(self):
        x, y = self.position
        self.position = (x - 1, y)
        print(f"[Turn] 왼쪽 회전 → 새로운 위치: {self.position}")

    def turn_right(self):
        x, y = self.position
        self.position = (x + 1, y)
        print(f"[Turn] 오른쪽 회전 → 새로운 위치: {self.position}")

    def stop(self):
        print(f"[Stop] 정지 → 현재 위치 유지: {self.position}")

    def execute_action(self, action):
        if action == "전진":
            self.move_forward()
        elif action == "왼쪽 회전":
            self.turn_left()
        elif action == "오른쪽 회전":
            self.turn_right()
        elif action == "정지":
            self.stop()

        self.path.append(self.position)

    def run_simulation(self, obstacles):
        plt.ion()
        for step in range(10):
            print(f"\n===== Step {step + 1} =====")
            sensors = update_sensor_data(self.position, obstacles)
            detections = detect_obstacles(sensors)
            action = decide_action(detections)
            self.execute_action(action)
            visualize_map(self.position, self.path, obstacles, step + 1)
            if action == "정지":
                print("[Simulation] 장애물로 인해 정지합니다.")
                break
        plt.ioff()
        plt.show()
        print(f"[Simulation] 최종 위치: {self.position}")

# 9번: 메인 실행
if __name__ == "__main__":
    print("[9] 메인 실행 시작")
    car = SimpleCar("현대차", 3, 0)
    obstacles = {(4, 5), (3, 3), (2, 0), (2, 4)}
    print("[9] 장애물 설정 완료:", obstacles)
    car.run_simulation(obstacles)
    print("[9] 프로그램 종료")
# Out:
# [9] 메인 실행 시작
# [Car Init] 자동차 현대차 생성, 초기 위치: (3, 0)
# [9] 장애물 설정 완료: {(4, 5), (3, 3), (2, 0), (2, 4)}
#
# ===== Step 1 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=3, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 3cm
# [Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 1cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 3
# [6-12]⚠️ 위험! 앞 방향 → 목록에 추가됨 (거리 3 < 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 1
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 1 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['앞', '왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 오른쪽 회전
# [Turn] 오른쪽 회전 → 새로운 위치: (4, 0)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 2 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=4, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 5cm
# [Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 2cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 5
# [6-12]⚠️ 위험! 앞 방향 → 목록에 추가됨 (거리 5 < 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 2
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 2 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['앞', '왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 오른쪽 회전
# [Turn] 오른쪽 회전 → 새로운 위치: (5, 0)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 3 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 3cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 3
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 3 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 1)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 4 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=1
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 2)
# ===== Step 5 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=2
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 3)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 6 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=3
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 2cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 2, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 2, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 2, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 2
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 2 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 4)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 7 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=4
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 3cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 3
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 3 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 5)
# ===== Step 8 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=5
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 1cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 1, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 1, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 1, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 1
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 1 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 6)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 9 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=6
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ===== Step 10 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=7
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 8)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-47-1817501543.py:139: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# [Simulation] 최종 위치: (5, 8)
# [9] 프로그램 종료

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# ✅ 한글 폰트 깨짐 방지 설정
mpl.rc('font', family='Malgun Gothic')  # macOS일 경우 'AppleGothic'로 바꿔주세요
mpl.rcParams['axes.unicode_minus'] = False  # 마이너스 부호 깨짐 방지

# 1번: 센서 초기화
def init_sensors():
    sensors = {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
    print("[1] 센서 초기화:", sensors)
    return sensors

# 2~4번: 센서 스캔
def scan_front(x, y, obstacles, sensors):
    front_distance = 15.0
    for ox, oy in obstacles:
        if ox == x and oy > y:
            distance = oy - y
            if distance < front_distance:
                front_distance = distance
    sensors['앞'] = front_distance
    print(f"[Front Scan] 현재 앞 센서 거리: {sensors['앞']}cm")
    if front_distance <= 5.0:
        print("[Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)")
    elif front_distance <= 10.0:
        print("[Front Scan] 앞에 장애물이 가까움 (10cm 이하)")
    elif front_distance <= 15.0:
        print("[Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Front Scan] 앞에 장애물 없음, 직진 가능")
    print("[Front Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

def scan_left(x, y, obstacles, sensors):
    left_distance = 15.0
    for ox, oy in obstacles:
        if oy == y and ox < x:
            distance = x - ox
            if distance < left_distance:
                left_distance = distance
    sensors['왼쪽'] = left_distance
    print(f"[Left Scan] 현재 왼쪽 센서 거리: {sensors['왼쪽']}cm")
    if left_distance <= 5.0:
        print("[Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)")
    elif left_distance <= 10.0:
        print("[Left Scan] 왼쪽에 장애물이 가까움 (10cm 이하)")
    elif left_distance <= 15.0:
        print("[Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Left Scan] 왼쪽에 장애물 없음, 좌회전 가능")
    print("[Left Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

def scan_right(x, y, obstacles, sensors):
    right_distance = 15.0
    for ox, oy in obstacles:
        if oy == y and ox > x:
            distance = ox - x
            if distance < right_distance:
                right_distance = distance
    sensors['오른쪽'] = right_distance
    print(f"[Right Scan] 현재 오른쪽 센서 거리: {sensors['오른쪽']}cm")
    if right_distance <= 5.0:
        print("[Right Scan] 오른쪽에 장애물이 매우 가까움! (5cm 이하)")
    elif right_distance <= 10.0:
        print("[Right Scan] 오른쪽에 장애물이 가까움 (10cm 이하)")
    elif right_distance <= 15.0:
        print("[Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)")
    else:
        print("[Right Scan] 오른쪽에 장애물 없음, 우회전 가능")
    print("[Right Scan] 스캔 완료, 현재 센서 상태:", sensors)
    return sensors

# 5번: 센서 데이터 업데이트
def update_sensor_data(position, obstacles):
    print("[5-4] 센서 데이터 업데이트 시작")
    x, y = position
    print(f"[5-6] 현재 위치: x={x}, y={y}")
    sensors = init_sensors()
    sensors = scan_front(x, y, obstacles, sensors)
    sensors = scan_left(x, y, obstacles, sensors)
    sensors = scan_right(x, y, obstacles, sensors)
    print("[5-17] 센서 데이터 업데이트 완료:", sensors)
    return sensors

# 6번: 장애물 감지
def detect_obstacles(sensors):
    print("[6-4] 함수 시작")
    obstacles = []
    for direction, distance in sensors.items():
        print(f"[6-9] 현재 방향: {direction}, 거리: {distance}")
        if distance < 10.0:
            obstacles.append(direction)
            print(f"[6-12]⚠️ 위험! {direction} 방향 → 목록에 추가됨 (거리 {distance} < 10.0)")
        else:
            print(f"[6-14] ✅ 안전 {direction} 방향 (거리 {distance} ≥ 10.0)")
    print("[6-16] 장애물 감지 완료 → 최종 obstacles 리스트:", obstacles)
    return obstacles

# 7번: 행동 결정
def decide_action(obstacles):
    print("[7] 행동 결정 시작")
    if '앞' not in obstacles and '왼쪽' not in obstacles and '오른쪽' not in obstacles:
        action = "전진"
    elif '앞' in obstacles and '왼쪽' not in obstacles:
        action = "왼쪽 회전"
    elif '앞' in obstacles and '오른쪽' not in obstacles:
        action = "오른쪽 회전"
    elif '앞' in obstacles and '왼쪽' in obstacles and '오른쪽' in obstacles:
        action = "정지"
    else:
        action = "전진"
    print("[7] 행동 결정 완료 →", action)
    return action

# 시각화 함수
def visualize_map(car_position, path_history, obstacles, step):
    grid_size = 7
    plt.clf()
    plt.title(f"[시각화] Step {step} 자동차 위치")
    plt.xlim(-1, grid_size)
    plt.ylim(-1, grid_size)
    plt.xticks(range(grid_size))
    plt.yticks(range(grid_size))
    plt.grid(True)

    # 장애물
    for ox, oy in obstacles:
        plt.plot(ox, oy, 'ks', markersize=20)
        plt.text(ox - 0.3, oy + 0.3, "장애물", fontsize=9)

    # 경로
    if len(path_history) > 1:
        xs, ys = zip(*path_history)
        plt.plot(xs, ys, 'b--', linewidth=2, label='이동 경로')

    # 현재 위치 + 라벨
    x, y = car_position
    plt.plot(x, y, 'ro', markersize=20, label='자동차')
    plt.text(x + 0.2, y + 0.2, f"Step {step}", fontsize=9)

    plt.gca().set_aspect('equal', adjustable='box')
    plt.legend(loc='upper right')
    plt.pause(0.7)

# 8번: 자동차 클래스
class SimpleCar:
    def __init__(self, name, x, y):
        self.name = name
        self.position = (x, y)
        self.path = [self.position]
        print(f"[Car Init] 자동차 {self.name} 생성, 초기 위치: {self.position}")

    def move_forward(self):
        x, y = self.position
        self.position = (x, y + 1)
        print(f"[Move] 전진 → 새로운 위치: {self.position}")

    def turn_left(self):
        x, y = self.position
        self.position = (x - 1, y)
        print(f"[Turn] 왼쪽 회전 → 새로운 위치: {self.position}")

    def turn_right(self):
        x, y = self.position
        self.position = (x + 1, y)
        print(f"[Turn] 오른쪽 회전 → 새로운 위치: {self.position}")

    def stop(self):
        print(f"[Stop] 정지 → 현재 위치 유지: {self.position}")

    def execute_action(self, action):
        if action == "전진":
            self.move_forward()
        elif action == "왼쪽 회전":
            self.turn_left()
        elif action == "오른쪽 회전":
            self.turn_right()
        elif action == "정지":
            self.stop()
        self.path.append(self.position)

    def run_simulation(self, obstacles):
        plt.ion()
        for step in range(10):
            print(f"\n===== Step {step + 1} =====")
            sensors = update_sensor_data(self.position, obstacles)
            detections = detect_obstacles(sensors)
            action = decide_action(detections)
            self.execute_action(action)
            visualize_map(self.position, self.path, obstacles, step + 1)
            if action == "정지":
                print("[Simulation] 장애물로 인해 정지합니다.")
                break
        plt.ioff()
        plt.show()
        print(f"[Simulation] 최종 위치: {self.position}")

# 9번: 메인 실행
if __name__ == "__main__":
    print("[9] 메인 실행 시작")
    car = SimpleCar("현대차", 3, 0)
    obstacles = {(4, 5), (3, 3), (2, 0), (2, 4)}
    print("[9] 장애물 설정 완료:", obstacles)
    car.run_simulation(obstacles)
    print("[9] 프로그램 종료")
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# [9] 메인 실행 시작
# [Car Init] 자동차 현대차 생성, 초기 위치: (3, 0)
# [9] 장애물 설정 완료: {(4, 5), (3, 3), (2, 0), (2, 4)}
#
# ===== Step 1 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=3, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 3cm
# [Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 1cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 3, '왼쪽': 1, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 3
# [6-12]⚠️ 위험! 앞 방향 → 목록에 추가됨 (거리 3 < 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 1
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 1 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['앞', '왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 오른쪽 회전
# [Turn] 오른쪽 회전 → 새로운 위치: (4, 0)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ===== Step 2 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=4, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 5cm
# [Front Scan] 앞에 장애물이 매우 가까움! (5cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 2cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 5, '왼쪽': 2, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 5
# [6-12]⚠️ 위험! 앞 방향 → 목록에 추가됨 (거리 5 < 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 2
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 2 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['앞', '왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 오른쪽 회전
# [Turn] 오른쪽 회전 → 새로운 위치: (5, 0)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ===== Step 3 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=0
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 3cm
# [Left Scan] 왼쪽에 장애물이 매우 가까움! (5cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 3, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 3
# [6-12]⚠️ 위험! 왼쪽 방향 → 목록에 추가됨 (거리 3 < 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: ['왼쪽']
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 1)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ===== Step 4 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=1
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 2)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# /tmp/ipython-input-48-397095220.py:145: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.pause(0.7)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ===== Step 10 =====
# [5-4] 센서 데이터 업데이트 시작
# [5-6] 현재 위치: x=5, y=7
# [1] 센서 초기화: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Front Scan] 현재 앞 센서 거리: 15.0cm
# [Front Scan] 앞에 약간의 장애물 감지 (15cm 이하)
# [Front Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Left Scan] 현재 왼쪽 센서 거리: 15.0cm
# [Left Scan] 왼쪽에 약간의 장애물 감지 (15cm 이하)
# [Left Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [Right Scan] 현재 오른쪽 센서 거리: 15.0cm
# [Right Scan] 오른쪽에 약간의 장애물 감지 (15cm 이하)
# [Right Scan] 스캔 완료, 현재 센서 상태: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [5-17] 센서 데이터 업데이트 완료: {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# [6-4] 함수 시작
# [6-9] 현재 방향: 앞, 거리: 15.0
# [6-14] ✅ 안전 앞 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 왼쪽, 거리: 15.0
# [6-14] ✅ 안전 왼쪽 방향 (거리 15.0 ≥ 10.0)
# [6-9] 현재 방향: 오른쪽, 거리: 15.0
# [6-14] ✅ 안전 오른쪽 방향 (거리 15.0 ≥ 10.0)
# [6-16] 장애물 감지 완료 → 최종 obstacles 리스트: []
# [7] 행동 결정 시작
# [7] 행동 결정 완료 → 전진
# [Move] 전진 → 새로운 위치: (5, 8)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# [Simulation] 최종 위치: (5, 8)
# [9] 프로그램 종료
